# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file1 = '/Users/luyizhen/Desktop/bos.csv'
file2 = '/Users/luyizhen/Desktop/las.csv'
file3 = '/Users/luyizhen/Desktop/lax.csv'
file4 = '/Users/luyizhen/Desktop/sea.csv'
file5 = '/Users/luyizhen/Desktop/iah.csv'

# %%
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)
df5 = pd.read_csv(file5)

# %%
df1.index = df1['Date']
df2.index = df2['Date']
df3.index = df3['Date']
df4.index = df4['Date']
df5.index = df5['Date']

# %%
def get_daily_price(df,date):
    price1125 = df['Price']['11.25':'11.26']
    price1125_dec23 = price1125[date]
    p1125 = []
    for i in list(price1125_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1125.append(i)
    price1126 = df['Price']['11.26':'11.27']
    price1126_dec23 = price1125[date]
    p1126 = []
    for i in list(price1126_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1126.append(i)
    price1127 = df['Price']['11.27':'11.28']
    price1127_dec23 = price1127[date]
    p1127 = []
    for i in list(price1127_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1127.append(i)
    price1128 = df['Price']['11.28':'11.29']
    price1128_dec23 = price1128[date]
    p1128 = []
    for i in list(price1128_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1128.append(i)
    price1129 = df['Price']['11.29':'11.30.']
    price1129_dec23 = price1129[date]
    p1129 = []
    for i in list(price1129_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1129.append(i)
    price1130 = df['Price']['11.30.':'12.1']
    price1130_dec23 = price1130[date]
    p1130 = []
    for i in list(price1130_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1130.append(i)
    price1201 = df['Price']['12.1':'12.2']
    price1201_dec23 = price1201[date]
    p1201 = []
    for i in list(price1201_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1201.append(i)
    price1202 = df['Price']['12.2':'12.3']
    price1202_dec23 = price1202[date]
    p1202 = []
    for i in list(price1202_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1202.append(i)
    price1203 = df['Price']['12.3':'12.4']
    price1203_dec23 = price1203[date]
    p1203 = []
    for i in list(price1203_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1203.append(i)
    price1204 = df['Price']['12.4':'12.5']
    price1204_dec23 = price1204[date]
    p1204 = []
    for i in list(price1204_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1204.append(i)
    price1205 = df['Price']['12.5':'12.6']
    price1205_dec23 = price1205[date]
    p1205 = []
    for i in list(price1205_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1205.append(i)
    price1206 = df['Price']['12.6':'12.7']
    price1206_dec23 = price1206[date]
    p1206 = []
    for i in list(price1206_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1206.append(i)
    price1207 = df['Price']['12.7':'12.8']
    price1207_dec23 = price1125[date]
    p1207 = []
    for i in list(price1207_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1207.append(i)
    price1208 = df['Price']['12.8':'12.9']
    price1208_dec23 = price1208[date]
    p1208 = []
    for i in list(price1208_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1208.append(i)
    price1209 = df['Price']['12.9':'12.10.']
    price1209_dec23 = price1209[date]
    p1209 = []
    for i in list(price1209_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1209.append(i)
    price1210 = df['Price']['12.10.':'12.11']
    price1210_dec23 = price1210[date]
    p1210 = []
    for i in list(price1210_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1210.append(i)
    price1211 = df['Price']['12.11':'12.12']
    price1211_dec23 = price1211[date]
    p1211 = []
    for i in list(price1211_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1211.append(i)
    price1212 = df['Price']['12.12':'12.13']
    price1212_dec23 = price1212[date]
    p1212 = []
    for i in list(price1212_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1212.append(i)
    price1213 = df['Price']['12.13':'12.14']
    price1213_dec23 = price1213[date]
    p1213 = []
    for i in list(price1213_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1213.append(i)
    price1214 = df['Price']['12.14':]
    price1214_dec23 = price1214[date]
    p1214 = []
    for i in list(price1214_dec23):
        i = int(i.replace('$','').replace(',',''))
        p1214.append(i)
    a = p1125,p1126,p1127,p1128,p1129,p1130,p1201,p1202,p1203,p1204,p1205,p1206,p1207,p1208,p1209,p1210,p1211,p1212,p1213,p1214
    return a

# %%
y1 = get_daily_price(df1,"('Dec', 23)")
y2 = get_daily_price(df1,"('Dec', 24)")
y3 = get_daily_price(df1,"('Dec', 25)")
y4 = get_daily_price(df1,"('Dec', 26)")
y5 = get_daily_price(df1,"('Dec', 27)")
y6 = get_daily_price(df1,"('Dec', 28)")
y7 = get_daily_price(df1,"('Dec', 29)")
y8 = get_daily_price(df1,"('Dec', 30)")
y9 = get_daily_price(df1,"('Dec', 31)")
y10 = get_daily_price(df1,"('Jan', 1)")
y11 = get_daily_price(df1,"('Jan', 2)")

# %%
#BOS
plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y1,labels = labels,showmeans=True)
plt.title("12.23",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y2,labels = labels,showmeans=True)
plt.title("12.24",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y3,labels = labels,showmeans=True)
plt.title("12.25",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y4,labels = labels,showmeans=True)
plt.title("12.26",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y5,labels = labels,showmeans=True)
plt.title("12.27",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y6,labels = labels,showmeans=True)
plt.title("12.28",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y7,labels = labels,showmeans=True)
plt.title("12.29",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y8,labels = labels,showmeans=True)
plt.title("12.30",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y9,labels = labels,showmeans=True)
plt.title("12.31",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y10,labels = labels,showmeans=True)
plt.title("01.01",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y11,labels = labels,showmeans=True)
plt.title("01.02",fontsize = 30)
# Out:
# Text(0.5, 1.0, '01.02')

# %%
y1 = get_daily_price(df2,"('Dec', 23)")
y2 = get_daily_price(df2,"('Dec', 24)")
y3 = get_daily_price(df2,"('Dec', 25)")
y4 = get_daily_price(df2,"('Dec', 26)")
y5 = get_daily_price(df2,"('Dec', 27)")
y6 = get_daily_price(df2,"('Dec', 28)")
y7 = get_daily_price(df2,"('Dec', 29)")
y8 = get_daily_price(df2,"('Dec', 30)")
y9 = get_daily_price(df2,"('Dec', 31)")
y10 = get_daily_price(df2,"('Jan', 1)")
y11 = get_daily_price(df2,"('Jan', 2)")

# %%
#LAS
plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y1,labels = labels,showmeans=True)
plt.title("12.23",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y2,labels = labels,showmeans=True)
plt.title("12.24",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y3,labels = labels,showmeans=True)
plt.title("12.25",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y4,labels = labels,showmeans=True)
plt.title("12.26",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y5,labels = labels,showmeans=True)
plt.title("12.27",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y6,labels = labels,showmeans=True)
plt.title("12.28",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y7,labels = labels,showmeans=True)
plt.title("12.29",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y8,labels = labels,showmeans=True)
plt.title("12.30",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y9,labels = labels,showmeans=True)
plt.title("12.31",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y10,labels = labels,showmeans=True)
plt.title("01.01",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y11,labels = labels,showmeans=True)
plt.title("01.02",fontsize = 30)
# Out:
# Text(0.5, 1.0, '01.02')

# %%
y1 = get_daily_price(df3,"('Dec', 23)")
y2 = get_daily_price(df3,"('Dec', 24)")
y3 = get_daily_price(df3,"('Dec', 25)")
y4 = get_daily_price(df3,"('Dec', 26)")
y5 = get_daily_price(df3,"('Dec', 27)")
y6 = get_daily_price(df3,"('Dec', 28)")
y7 = get_daily_price(df3,"('Dec', 29)")
y8 = get_daily_price(df3,"('Dec', 30)")
y9 = get_daily_price(df3,"('Dec', 31)")
y10 = get_daily_price(df3,"('Jan', 1)")
y11 = get_daily_price(df3,"('Jan', 2)")

# %%
#LAX
plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y1,labels = labels,showmeans=True)
plt.title("12.23",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y2,labels = labels,showmeans=True)
plt.title("12.24",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y3,labels = labels,showmeans=True)
plt.title("12.25",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y4,labels = labels,showmeans=True)
plt.title("12.26",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y5,labels = labels,showmeans=True)
plt.title("12.27",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y6,labels = labels,showmeans=True)
plt.title("12.28",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y7,labels = labels,showmeans=True)
plt.title("12.29",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y8,labels = labels,showmeans=True)
plt.title("12.30",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y9,labels = labels,showmeans=True)
plt.title("12.31",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y10,labels = labels,showmeans=True)
plt.title("01.01",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y11,labels = labels,showmeans=True)
plt.title("01.02",fontsize = 30)
# Out:
# Text(0.5, 1.0, '01.02')

# %%
y1 = get_daily_price(df4,"('Dec', 23)")
y2 = get_daily_price(df4,"('Dec', 24)")
y3 = get_daily_price(df4,"('Dec', 25)")
y4 = get_daily_price(df4,"('Dec', 26)")
y5 = get_daily_price(df4,"('Dec', 27)")
y6 = get_daily_price(df4,"('Dec', 28)")
y7 = get_daily_price(df4,"('Dec', 29)")
y8 = get_daily_price(df4,"('Dec', 30)")
y9 = get_daily_price(df4,"('Dec', 31)")
y10 = get_daily_price(df4,"('Jan', 1)")
y11 = get_daily_price(df4,"('Jan', 2)")

# %%
#SEA
plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y1,labels = labels,showmeans=True)
plt.title("12.23",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y2,labels = labels,showmeans=True)
plt.title("12.24",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y3,labels = labels,showmeans=True)
plt.title("12.25",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y4,labels = labels,showmeans=True)
plt.title("12.26",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y5,labels = labels,showmeans=True)
plt.title("12.27",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y6,labels = labels,showmeans=True)
plt.title("12.28",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y7,labels = labels,showmeans=True)
plt.title("12.29",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y8,labels = labels,showmeans=True)
plt.title("12.30",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y9,labels = labels,showmeans=True)
plt.title("12.31",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y10,labels = labels,showmeans=True)
plt.title("01.01",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y11,labels = labels,showmeans=True)
plt.title("01.02",fontsize = 30)
# Out:
# Text(0.5, 1.0, '01.02')

# %%
y1 = get_daily_price(df5,"('Dec', 23)")
y2 = get_daily_price(df5,"('Dec', 24)")
y3 = get_daily_price(df5,"('Dec', 25)")
y4 = get_daily_price(df5,"('Dec', 26)")
y5 = get_daily_price(df5,"('Dec', 27)")
y6 = get_daily_price(df5,"('Dec', 28)")
y7 = get_daily_price(df5,"('Dec', 29)")
y8 = get_daily_price(df5,"('Dec', 30)")
y9 = get_daily_price(df5,"('Dec', 31)")
y10 = get_daily_price(df5,"('Jan', 1)")
y11 = get_daily_price(df5,"('Jan', 2)")

# %%
#IAH
plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y1,labels = labels,showmeans=True)
plt.title("12.23",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y2,labels = labels,showmeans=True)
plt.title("12.24",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y3,labels = labels,showmeans=True)
plt.title("12.25",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y4,labels = labels,showmeans=True)
plt.title("12.26",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y5,labels = labels,showmeans=True)
plt.title("12.27",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y6,labels = labels,showmeans=True)
plt.title("12.28",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y7,labels = labels,showmeans=True)
plt.title("12.29",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y8,labels = labels,showmeans=True)
plt.title("12.30",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y9,labels = labels,showmeans=True)
plt.title("12.31",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y10,labels = labels,showmeans=True)
plt.title("01.01",fontsize = 30)

plt.figure(figsize=(15,7))
labels = '11.25','11.26','11.27','11.28','11.29','11.30','12.01','12.02','12.03','12.04','12.05','12.06','12.07','12.08','12.09','12.10','12.11','12.12','12.13','12.14'
plt.boxplot(y11,labels = labels,showmeans=True)
plt.title("01.02",fontsize = 30)
# Out:
# Text(0.5, 1.0, '01.02')
